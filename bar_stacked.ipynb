# %%
# %matplotlib inline

# %% [markdown]
# # Stacked Bar Graph
#
#
# This is an example of creating a stacked bar plot with error bars
# using `~matplotlib.pyplot.bar`.  Note the parameters *yerr* used for
# error bars, and *bottom* to stack the women's bars on top of the men's
# bars.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
a = [9]
b = [151]
c = [30]
d = [225]
e = [80]
f = [10]
g = [21.5]
h = [1080]
i = [888.5]
j = [17]
k = [659.5]
l = [2400]

# %%
df = pd.DataFrame({'a' : a,'b' : b, 'c' : c,'d' : d,'e' : e, 'f' : f,'g' : g,'h' : h, 'i' : i,'j' : j,'k' : k, 'l' : l })
ax = df.plot.barh(stacked=True);
ax.figure.set_size_inches(20,8)

ax.set_title("0-5250KHz")
ax.legend(loc='upper right')

# %%
a = [5250]
b = [230]
c = [420]
d = [50]
e = [250]
f = [325]
g = [240]
h = [235]
i = [200]
j = [250]
k = [1365]
l = [225]
m = [955]
n = [1405]
o = [830]
p = [2800]

# %%
df = pd.DataFrame({'a' : a,'b' : b, 'c' : c,'d' : d,'e' : e, 'f' : f,'g' : g,'h' : h, 'i' : i,'j' : j,'k' : k, 'l' : l, 'm' : m,'n' : n,'o' : o, 'p' : p })
ax = df.plot.barh(stacked=True);
ax.figure.set_size_inches(20,8)

ax.set_title("0-14990KHz")
ax.legend(loc='upper right')

# %%
a = [15010]
b = [90]
c = [700]
d = [2268]
e = [1922]
f = [5]
g = [15]
h = [990]
i = [350]
j = [474]
k = [2453]
l = [2774500]
m = [5925500]
n = [9479500]

# %%
df = pd.DataFrame({'a' : a,'b' : b, 'c' : c,'d' : d,'e' : e, 'f' : f,'g' : g,'h' : h, 'i' : i,'j' : j,'k' : k, 'l' : l, 'm' : m,'n' : n})
ax = df.plot.barh(stacked=True);
ax.figure.set_size_inches(20,8)

ax.set_title("0-154.04MHz")
ax.legend(loc='upper right')
